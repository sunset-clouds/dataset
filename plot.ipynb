# %%
import numpy as np
import matplotlib.pyplot as plt

X = np.array(range(1, 7))
Y = np.array(range(1, 7))

X2 = np.array(range(2, 8))
Y2 = np.array(range(4,10))
#label = (-1,-1,0,0,1,1)
label = (0,0,1,1,2,2)
plt.scatter(X.reshape(6), Y.reshape(6), c = 'blue', s = 180)
plt.scatter(X2.reshape(6), Y2.reshape(6), c = 'red', s = 180)
plt.show()

# %%
A = np.array([1,2,3,4,5])
print(A[0:4])
# Out:
# [1 2 3 4]

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(1)

X = np.random.randn(1, 10)
Y = np.random.randn(1, 10)
print(X,Y)
label = np.array([1,1,0,0,0,0,0,1,1,1])

plt.scatter(X.reshape(10), Y.reshape(10), c =label, s = 180, cmap = plt.cm.Spectral)
plt.show()
# Out:
# [[ 1.62434536 -0.61175641 -0.52817175 -1.07296862  0.86540763 -2.3015387
#    1.74481176 -0.7612069   0.3190391  -0.24937038]] [[ 1.46210794 -2.06014071 -0.3224172  -0.38405435  1.13376944 -1.09989127
#   -0.17242821 -0.87785842  0.04221375  0.58281521]]
